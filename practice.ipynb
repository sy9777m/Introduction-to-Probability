# %%
from symbulate import *

# %%
probs = Hypergeometric(n=30, N1=20, N0=80).pmf(range(7, 31))
probs
# Out:
# array([1.80287211e-01, 1.16176457e-01, 5.77600464e-02, 2.22376179e-02,
#        6.62820205e-03, 1.52341741e-03, 2.67853610e-04, 3.55743076e-05,
#        3.50270105e-06, 2.48771382e-07, 1.22310776e-08, 3.89715707e-10,
#        7.13438366e-12, 5.60558716e-14, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
sum(probs)
# Out:
# 0.38492014376630085

# %%
1 - Hypergeometric(n=30, N1=20, N0=80).cdf(6)
# Out:
# 0.3849201437663008

# %%
probs = Binomial(n=51, p=0.01).pmf(range(2, 51, 2))
probs
# Out:
# array([7.79174480e-02, 1.55818996e-03, 1.14573571e-05, 4.13324569e-08,
#        8.46244910e-11, 1.07274277e-13, 8.91255091e-17, 5.04689904e-20,
#        2.00253338e-23, 5.67792557e-27, 1.16616574e-30, 1.75027722e-34,
#        1.92868014e-38, 1.56177790e-42, 9.26787459e-47, 4.00356955e-51,
#        1.24511721e-55, 2.74244677e-60, 4.17928311e-65, 4.26413949e-70,
#        2.77920480e-75, 1.07909959e-80, 2.23393269e-86, 2.02064767e-92,
#        5.04900000e-99])

# %%
sum(probs)
# Out:
# 0.079487136776526

# %%
probs = NegativeBinomial(r=10, p=0.15).pmf(range(10, 41))
1 - sum(probs)
# Out:
# 0.9327797386121518

# %%
1 - NegativeBinomial(r=10, p=0.15).cdf(40)
# Out:
# 0.9327797386121518

# %%
probs = Poisson(10).pmf(range(12))
1 - sum(probs)
# Out:
# 0.303223853696892

# %%
1 - Poisson(10).cdf(11), 1 - Binomial(n=10 ** 4, p=10 ** -3).cdf(11)
# Out:
# (0.30322385369689386, 0.3031669333250695)

# %%
x = 12
while Poisson(10).cdf(x) < .99:
    x += 1

x, Poisson(10).cdf(x)
# Out:
# (18, 0.9928134953961456)

# %%
Poisson(0.8 * (1 - 0)).pmf(1) * (1 - Poisson(0.8 * (4 - 1)).cdf(1))
# Out:
# 0.24858997647262118

# %%
Binomial(n=6, p=0.5).cdf(2)
# Out:
# 0.34375

# %%
Exponential(0.3).plot()

# %%
Exponential(0.3).cdf(5) - Exponential(0.3).cdf(1)
# Out:
# 0.5176880605332881

# %%
L = RV(Uniform(a=0, b=4))
A = (L / 4) ** 2

L.sim(10000).plot()
A.sim(10000).plot()

# %%
Normal().plot()

# %%
Normal().cdf(1)
# Out:
# 0.8413447460685429

# %%
1 - Normal().cdf(-0.5)
# Out:
# 0.6914624612740131

# %%
Normal().cdf(2) - Normal().cdf(-1)
# Out:
# 0.8185946141203637

# %%
1 - Binomial(n=300, p=2/38).cdf(21)
# Out:
# 0.07497808822239194

# %%
1 - Normal(mean=300 * 2/38, sd=sqrt(300 * 2/38 * (1 - 2/38))).cdf(22)
# Out:
# 0.054161500900249515
